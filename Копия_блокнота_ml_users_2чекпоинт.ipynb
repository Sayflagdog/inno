# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayflagdog/inno/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_ml_users_2%D1%87%D0%B5%D0%BA%D0%BF%D0%BE%D0%B8%D0%BD%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fuzzywuzzy
# !pip install rapidfuzz
import pandas as pd
from rapidfuzz import fuzz, process
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (3.10.0)

# %%
pd.set_option('display.max_columns', 30)

# %%
# df = pd.read_csv('main1.csv',skipinitialspace=True, nrows = 1_000)
# df2 = pd.read_csv('main2.csv',skipinitialspace=True, nrows = 1_000)
# df3 = pd.read_csv('main3.csv',skipinitialspace=True, nrows = 1_000)

# %%
df = pd.read_csv('main1.csv',skipinitialspace=True)

# %%
df2 = pd.read_csv('main2.csv',skipinitialspace=True)

# %%
df3 = pd.read_csv('main3.csv',skipinitialspace=True)

# %%
df = df.applymap(lambda s: s.lower() if type(s) == str else s)
df2 = df2.applymap(lambda s: s.lower() if type(s) == str else s)
df3 = df3.applymap(lambda s: s.lower() if type(s) == str else s)
# Out:
# <ipython-input-7-ba1dcd969689>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda s: s.lower() if type(s) == str else s)
# <ipython-input-7-ba1dcd969689>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2 = df2.applymap(lambda s: s.lower() if type(s) == str else s)
# <ipython-input-7-ba1dcd969689>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df3 = df3.applymap(lambda s: s.lower() if type(s) == str else s)

# %%
df3
# Out:
#                                       uid                        name  \
# 0    9185f879-6289-4ad6-9cb0-ed7cb6cb652b          мамасаид ьадкибаев
# 1    289fcf9e-af05-43cf-a6d4-1d1d3cf5131f                ютта игинова
# 2    c2b04755-ebd8-4625-b8bb-4131ca049415             зафер миродилов
# 3    49978ae8-51fe-4a74-908e-22ec9e693855             шахзода боровая
# 4    75e199c5-86fa-4d3b-b1ea-783ecc26b021           нурсулу курбонова
# ..                                    ...                         ...
# 995  40fbbfc2-2478-41ec-af6b-762fa857b79e  сейитгелди маткаримов угли
# 996  06f78a2d-1ded-4148-a7a6-1dddcb713e2e            любовь доктурбек
# 997  47423e04-c0ab-403f-9012-0a542d33da76         анксtасия 5шипвнова
# 998  ade1c562-cea9-47a3-8ad4-320d24c3e013                борис епихин
# 999  50d3679d-0093-4e67-b16a-d2562103bbad        бернхард исматиллаев
#
#                                    email   birthdate sex
# 0         mamasaid_balkibaev0@example.ru  9145-06-15   m
# 1                  jutta_ihinova1;yanddx  1981-11-24   f
# 2               zafer_mirodilov2@mail.ru        1954   m
# 3           shahzoda_borovaja3@gmail.com  2989-07-15   f
# 4         nursulu_kurbonova4@example.org  2000-10-21   f
# ..                                   ...         ...  ..
# 995  sejitgeldi_matkarimov1018@yandex.ru  1955-03-31   m
# 996     ljubov_dokturbek1019@example.org   946-10-02   f
# 997   anzstssija_shipunova762;example.ru        1997   f
# 998         boris_epihin1020@example.net  1957-12-12   m
# 999        betnhard_ismariloaev1021@mail  1964-09-06   m
#
# [1000 rows x 5 columns]

# %%
# count = 80
# go = -1
# end = 0
# for i in df2['first_name'] + ' ' + df2['middle_name'] + ' ' + df2['last_name'] :
#   go+=1
#   for j in df['full_name']:
#      name_similarity = fuzz.WRatio(i , j)
#      name_similarity2 = fuzz.token_sort_ratio(i , j)
#      name_similarity_all = (name_similarity2 + name_similarity) / 2
#      if name_similarity_all >= count:
#         df_full_concat = pd.concat([
#             df.iloc[end],
#             df2.iloc[go]
#         ],axis = 1)
#         #  print(df_full_concat)
#         end+=1

# %%
count = 70
results = []

df2_full_names = df2['first_name'] + ' ' + df2['middle_name'] + ' ' + df2['last_name']
df3_full_names = df3['name']

for go, i in enumerate(df2_full_names):

    matches_df = process.extract(i, df['full_name'], scorer=fuzz.WRatio, limit=5)


    for match_df in matches_df:
        j = match_df[0]
        name_similarity = match_df[1]
        name_similarity2 = fuzz.token_sort_ratio(i, j)
        name_similarity_all = (name_similarity2 + name_similarity) / 2


        if name_similarity_all >= count:

            matches_df3 = process.extract(i, df3_full_names, scorer=fuzz.WRatio, limit=5)


            for match_df3 in matches_df3:
                k = match_df3[0]
                name_similarity3 = match_df3[1]
                name_similarity4 = fuzz.token_sort_ratio(i, k)
                name_similarity_all3 = (name_similarity3 + name_similarity4) / 2

                if name_similarity_all3 >= count:
                    results.append(pd.concat([
                        df.loc[df['full_name'] == j],
                        df2.iloc[[go]],
                        df3.loc[df3['name'] == k]
                    ], axis=1))


if results:
    df_full_concat = pd.concat(results, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-5104d5ee71d7> in <cell line: 7>()
#      19         if name_similarity_all >= count:
#      20
# ---> 21             matches_df3 = process.extract(i, df3_full_names, scorer=fuzz.WRatio, limit=5)
#      22
#      23
#
# src/rapidfuzz/process_cpp_impl.pyx in rapidfuzz.process_cpp_impl.extract()
#
# src/rapidfuzz/process_cpp_impl.pyx in rapidfuzz.process_cpp_impl.extract_dict()
#
# src/rapidfuzz/process_cpp_impl.pyx in rapidfuzz.process_cpp_impl.extract_dict_f64()
#
# KeyboardInterrupt:

# %%
df_full_concat
# Out:
#                                       uid                         full_name  \
# 0    2b401a4a-33c0-47e0-b527-300e17b3a8da            миродилов зафер роберт
# 1                                     NaN                               NaN
# 2    a844b52d-6fc8-4aac-9180-092cf3cba7b0           5миродилов зафер роберт
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ..                                    ...                               ...
# 299                                   NaN                               NaN
# 300                                   NaN                               NaN
# 301  b4ae5e31-5133-47f7-91ae-15d9581cd822  абдуманнонова марина мирзошоевна
# 302                                   NaN                               NaN
# 303                                   NaN                               NaN
#
#                                     email  \
# 0                zafer_mirodilov2@mail.ru
# 1                                     NaN
# 2                    zafer_mirodilov2mail
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 299                                   NaN
# 300                                   NaN
# 301  marina_abdumannonova1005@example.com
# 302                                   NaN
# 303                                   NaN
#
#                                                address  sex   birthdate  \
# 0    ст. красногорск (моск.), ул. урожайная, д. 4/9...    m  1954-07-03
# 1                                                  NaN  NaN         NaN
# 2    ст. красногорск (моск.), ул. урожайная, д. 4/9...    m   954-01-01
# 3                                                  NaN  NaN         NaN
# 4                                                  NaN  NaN         NaN
# ..                                                 ...  ...         ...
# 299                                                NaN  NaN         NaN
# 300                                                NaN  NaN         NaN
# 301  г. богучар, пер. родниковый, д. 2/2 стр. 296, ...    f  1990-03-22
# 302                                                NaN  NaN         NaN
# 303                                                NaN  NaN         NaN
#
#                  phone                                   uid first_name  \
# 0      +7 585 762 7855                                   NaN        NaN
# 1                  NaN  7ac130fe-690e-4e39-9b25-b141095f3eec      зафер
# 2    +7 (585) 762 7855                                   NaN        NaN
# 3                  NaN  7ac130fe-690e-4e39-9b25-b141095f3eec      зафер
# 4                  NaN                                   NaN        NaN
# ..                 ...                                   ...        ...
# 299                NaN  add7ebf6-57ce-474d-b780-814b7b77d8bd     максим
# 300                NaN                                   NaN        NaN
# 301     8 667 478 4706                                   NaN        NaN
# 302                NaN  967880e2-2220-4221-b4bb-94192ea86ffb     марина
# 303                NaN                                   NaN        NaN
#
#      middle_name      last_name   birthdate              phone  \
# 0            NaN            NaN         NaN                NaN
# 1         роберт     мииродилов  1954-07-03  +7 (585) 762 7855
# 2            NaN            NaN         NaN                NaN
# 3         роберт     мииродилов  1954-07-03  +7 (585) 762 7855
# 4            NaN            NaN         NaN                NaN
# ..           ...            ...         ...                ...
# 299       амиршo         куляев  1996-12-24   8 (866) 810-0707
# 300          NaN            NaN         NaN                NaN
# 301          NaN            NaN         NaN                NaN
# 302  мирзошоевна  абдуманнонова  1990-01-01   8 (667) 478 4706
# 303          NaN            NaN         NaN                NaN
#
#                                                address  \
# 0                                                  NaN
# 1    ст. красногорск (моск.), ул. урожайная, д. 4/9...
# 2                                                  NaN
# 3    ст. красногорск (моск.), ул. урожайная, д. 4/9...
# 4                                                  NaN
# ..                                                 ...
# 299  п. северобайкальск, ул. королева, д. 1 стр. 65...
# 300                                                NaN
# 301                                                NaN
# 302  г. богучар, пер. родниковый, д. 2/2 стр. 296, ...
# 303                                                NaN
#
#                                       uid                  name  \
# 0    c2b04755-ebd8-4625-b8bb-4131ca049415       зафер миродилов
# 1                                     NaN                   NaN
# 2                                     NaN                   NaN
# 3                                     NaN                   NaN
# 4    c2b04755-ebd8-4625-b8bb-4131ca049415       зафер миродилов
# ..                                    ...                   ...
# 299                                   NaN                   NaN
# 300  04277578-391a-4be1-9d26-ab27c09920ca         максим куляев
# 301                                   NaN                   NaN
# 302                                   NaN                   NaN
# 303  78c308f0-4635-4fe1-82f0-cf0a136dcb0b  марина абдуманнонова
#
#                                     email   birthdate  sex
# 0                zafer_mirodilov2@mail.ru        1954    m
# 1                                     NaN         NaN  NaN
# 2                                     NaN         NaN  NaN
# 3                                     NaN         NaN  NaN
# 4                zafer_mirodilov2@mail.ru        1954    m
# ..                                    ...         ...  ...
# 299                                   NaN         NaN  NaN
# 300             maksim_kuljaev987@mail.ru  1996-12-24    m
# 301                                   NaN         NaN  NaN
# 302                                   NaN         NaN  NaN
# 303  marina_abdumannonova1005@example.org  1990-03-22    f
#
# [304 rows x 19 columns]

# %%
count = 75
result_fuzzy = []


full_names = df_full_concat['full_name']

for i, name_i in enumerate(full_names):
    matches = process.extract(name_i, full_names, scorer=fuzz.WRatio, limit=5)
    for match in matches:
        name_j = match[0]
        name_similarity = match[1]

        if name_similarity >= count and name_i != name_j:
            result_fuzzy.append({
                'name_1': name_i,
                'name_2': name_j,
                'similarity': name_similarity
            })

if result_fuzzy:
    result_fuzzy_df = pd.DataFrame(result_fuzzy)
else:
    result_fuzzy_df = pd.DataFrame(columns=['name_1', 'name_2', 'similarity'])

result_fuzzy_df.to_csv('result_fuzzy.csv', index=False)

# %%
result_fuzzy_df
# Out:
#                                               name_1  \
# 0                             миродилов зафер роберт
# 1                            5миродилов зафер роберт
# 2                              крилов оглы юрий якуп
# 3                              крилов оглы юрий якуп
# 4   абдугаффуров джемал саипжонович оглы саипжонович
# 5   абдугаффуров джемал саипжонович оглы саипжонович
# 6   абдугаффуров джемал саипжонович оглы саипжонович
# 7   абдугаффуров джемал саипжонович оглы саипжонович
# 8                      матякубова оглы франсес иоана
# 9                      матякубова оглы франсес иоана
# 10                         кунцевич нурзат николевна
# 11                       5kунцевич ну-рзаt николевна
# 12                          иргашев оглы алишер эрик
# 13                          иргашев оглы алишер эрик
# 14                          устименко огли юлия сынь
# 15      абдуназаров  идибег вилььеввич оглы вильевич
# 16      абдуназаров  идибег вилььеввич оглы вильевич
# 17      абдуназаров  идибег вилььеввич оглы вильевич
# 18      абдуназаров  идибег вилььеввич оглы вильевич
# 19                           гуломов сергий иванович
# 20             гуломов сергий иванович огли иванович
# 21             гуломов сергий иванович огли иванович
# 22           овчигнникоуа угли диилнозахон сергеевна
# 23           овчигнникоуа угли диилнозахон сергеевна
# 24           овчигнникоуа угли диилнозахон сергеевна
# 25           овчигнникоуа угли диилнозахон сергеевна
# 26                     асипенок оглы фарида олеговна
# 27                     асипенок оглы фарида олеговна
# 28                         ланджев угли фаридун уулу
# 29                         ланджев угли фаридун уулу
# 30                         эркинзода мухлиса нуровна
# 31                         эркинжода иухлиса нуровна
# 32                         тошматова угли зоре шейла
# 33                         тошматова угли зоре шейла
# 34                     роллан фирдавс хосе оглы хосе
# 35                     роллан фирдавс хосе оглы хосе
#
#                                               name_2  similarity
# 0                            5миродилов зафер роберт   97.777778
# 1                             миродилов зафер роберт   97.777778
# 2   абдугаффуров джемал саипжонович оглы саипжонович   85.500000
# 3       абдуназаров  идибег вилььеввич оглы вильевич   85.500000
# 4                              крилов оглы юрий якуп   85.500000
# 5                      матякубова оглы франсес иоана   85.500000
# 6                           иргашев оглы алишер эрик   85.500000
# 7                      асипенок оглы фарида олеговна   85.500000
# 8   абдугаффуров джемал саипжонович оглы саипжонович   85.500000
# 9       абдуназаров  идибег вилььеввич оглы вильевич   85.500000
# 10                       5kунцевич ну-рзаt николевна   88.461538
# 11                         кунцевич нурзат николевна   88.461538
# 12  абдугаффуров джемал саипжонович оглы саипжонович   85.500000
# 13      абдуназаров  идибег вилььеввич оглы вильевич   85.500000
# 14             гуломов сергий иванович огли иванович   85.500000
# 15                             крилов оглы юрий якуп   85.500000
# 16                     матякубова оглы франсес иоана   85.500000
# 17                          иргашев оглы алишер эрик   85.500000
# 18                     асипенок оглы фарида олеговна   85.500000
# 19             гуломов сергий иванович огли иванович   90.000000
# 20                           гуломов сергий иванович   90.000000
# 21                          устименко огли юлия сынь   85.500000
# 22                         ланджев угли фаридун уулу   85.500000
# 23                         тошматова угли зоре шейла   85.500000
# 24                         ланджев угли фаридун уулу   85.500000
# 25                         тошматова угли зоре шейла   85.500000
# 26  абдугаффуров джемал саипжонович оглы саипжонович   85.500000
# 27      абдуназаров  идибег вилььеввич оглы вильевич   85.500000
# 28           овчигнникоуа угли диилнозахон сергеевна   85.500000
# 29           овчигнникоуа угли диилнозахон сергеевна   85.500000
# 30                         эркинжода иухлиса нуровна   92.000000
# 31                         эркинзода мухлиса нуровна   92.000000
# 32           овчигнникоуа угли диилнозахон сергеевна   85.500000
# 33           овчигнникоуа угли диилнозахон сергеевна   85.500000
# 34  абдугаффуров джемал саипжонович оглы саипжонович   85.500000
# 35      абдуназаров  идибег вилььеввич оглы вильевич   85.500000

# %%
# df_full_concat['index'] = 1
# df_full_concat = df_full_concat.drop(columns = 'index')
# df_full_concat
